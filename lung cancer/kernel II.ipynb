# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import skimage, os
from skimage.morphology import ball, disk, dilation, binary_erosion, remove_small_objects, erosion, closing, reconstruction, binary_closing
from skimage.measure import label,regionprops, perimeter
from skimage.morphology import binary_dilation, binary_opening
from skimage.filters import roberts, sobel
from skimage import measure, feature
from skimage.segmentation import clear_border
from skimage import data
from scipy import ndimage as ndi
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import dicom
import scipy.misc
import numpy as np


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %%
from subprocess import check_output
print(check_output(["ls", "/media/shihyu_chen/HD/Kaggle local/lung cancer/Input/[2]kaggle/"]).decode("utf8"))
# Out:
# data_password.txt
# sample_images
# sample_images.7z
# stage1
# stage1.7z
# stage1_labels.csv
# stage1_sample_submission.csv
# stage1_solution.csv
# stage2
# stage2.7z
# stage2_data_password.txt
# stage2_sample_submission.csv

# %%
# Any results you write to the current directory are saved as output.
lung = dicom.read_file('/media/shihyu_chen/HD/Kaggle local/lung cancer/Input/[2]kaggle/sample_images/0a0c32c9e08cc2ea76a71649de56be6d/0a67f9edb4915467ac16a565955898d3.dcm')

slice = lung.pixel_array
slice[slice == -2000] = 0
plt.imshow(slice, cmap=plt.cm.gray)
plt.show()
